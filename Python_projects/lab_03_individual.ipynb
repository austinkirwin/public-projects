# %% [markdown]
# # STAT 207 Lab Assignment 3 - Individual Part - [21 total points] - Solutions

# %% [markdown]
# ## <u>Case Study</u>: Preliminary Analysis and Pre-Cleaning for a Linear Regression Model
#
# In this case study we will explore and answer a preliminary analysis question based on the dataset that can be found in the `coffee_top_varieties.csv` file. Each row in this dataset represents a brand of coffee, **however we are only considering the 4 most popular varieties of coffee**.
#
# Click on this link to learn more about what each of the variables represent. https://corgis-edu.github.io/corgis/csv/coffee/
#
# <p>&nbsp;</p>
# <table style="border: none;border-collapse: collapse;width:102pt;">
#     <tbody>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;width:51pt;">Problem</td>
#             <td style="color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;border-left:none;width:51pt;">Points</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.5</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.6</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.7</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.1</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.2</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.3</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3.5</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#         <tr>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4</td>
#             <td style="color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1.5</td>
#         </tr>
#     </tbody>
# </table>
#
#
# ## 1. Initial Dataset Inspection
#
# 1. Read the csv file into a dataframe.
# 2. Display the first 5 rows.
# 3. Show the number of rows in the dataframe.

# %%
import pandas as pd 
df = pd.read_csv("coffee_top_varieties.csv")
df
# Out:
#     Location.Country Location.Region  Location.Altitude.Min  \
# 0             Brazil  south of minas                   1250
# 1             Brazil   vale da grama                   1300
# 2             Brazil  south of minas                   1250
# 3             Brazil  south of minas                   1250
# 4             Brazil  south of minas                   1200
# ..               ...             ...                    ...
# 577        Guatemala      san marcos                   1700
# 578        Guatemala      santa rosa                   1219
# 579         Honduras      ocotepeque                   1650
# 580        Guatemala      san marcos                   1700
# 581         Honduras       comayagua                   1400
#
#      Location.Altitude.Max  Location.Altitude.Average  Year  \
# 0                     1250                       1250  2011
# 1                     1300                       1300  2011
# 2                     1250                       1250  2011
# 3                     1250                       1250  2011
# 4                     1200                       1200  2011
# ..                     ...                        ...   ...
# 577                   1700                       1700  2017
# 578                   1219                       1219  2017
# 579                   1650                       1650  2017
# 580                   1700                       1700  2017
# 581                   1400                       1400  2017
#
#                     Data.Owner Data.Type.Species Data.Type.Variety  \
# 0                     nucoffee           Arabica           Bourbon
# 1                     nucoffee           Arabica           Bourbon
# 2                     nucoffee           Arabica           Bourbon
# 3                     nucoffee           Arabica           Bourbon
# 4                     nucoffee           Arabica           Bourbon
# ..                         ...               ...               ...
# 577  juan luis alvarado romero           Arabica           Bourbon
# 578  juan luis alvarado romero           Arabica           Bourbon
# 579       janny marlith torres           Arabica            Catuai
# 580  juan luis alvarado romero           Arabica           Bourbon
# 581            bismarck castro           Arabica           Caturra
#
#     Data.Type.Processing method  ...  Data.Scores.Flavor  \
# 0                 Natural / Dry  ...                8.50
# 1                 Natural / Dry  ...                8.17
# 2     Semi-washed / Semi-pulped  ...                8.00
# 3     Semi-washed / Semi-pulped  ...                8.00
# 4                 Natural / Dry  ...                7.92
# ..                          ...  ...                 ...
# 577                Washed / Wet  ...                7.25
# 578                Washed / Wet  ...                7.42
# 579                Washed / Wet  ...                7.00
# 580                Washed / Wet  ...                7.67
# 581                         NaN  ...                0.00
#
#      Data.Scores.Aftertaste  Data.Scores.Acidity  Data.Scores.Body  \
# 0                      8.00                 8.00              8.00
# 1                      8.00                 7.75              8.00
# 2                      8.00                 8.00              7.75
# 3                      8.00                 7.67              7.75
# 4                      7.75                 7.75              8.00
# ..                      ...                  ...               ...
# 577                    6.92                 7.33              7.25
# 578                    7.33                 7.42              7.50
# 579                    6.75                 6.92              7.00
# 580                    7.42                 7.42              7.67
# 581                    0.00                 0.00              0.00
#
#      Data.Scores.Balance  Data.Scores.Uniformity  Data.Scores.Sweetness  \
# 0                   8.00                   10.00                  10.00
# 1                   8.00                   10.00                  10.00
# 2                   8.00                   10.00                  10.00
# 3                   8.00                   10.00                  10.00
# 4                   7.75                   10.00                  10.00
# ..                   ...                     ...                    ...
# 577                 7.33                    9.33                  10.00
# 578                 7.42                    8.67                   9.33
# 579                 6.92                   10.00                  10.00
# 580                 7.67                    8.67                   8.67
# 581                 0.00                    0.00                   0.00
#
#      Data.Scores.Moisture  Data.Scores.Total  Data.Color
# 0                    0.12              86.92       Green
# 1                    0.12              86.42       Green
# 2                    0.11              86.08  Blue-Green
# 3                    0.11              85.42  Blue-Green
# 4                    0.11              84.92       Green
# ..                    ...                ...         ...
# 577                  0.10              79.83       Green
# 578                  0.10              79.17       Green
# 579                  0.11              79.17       Green
# 580                  0.10              79.08       Green
# 581                  0.12               0.00       Green
#
# [582 rows x 23 columns]

# %%
df.head()
# Out:
#   Location.Country Location.Region  Location.Altitude.Min  \
# 0           Brazil  south of minas                   1250
# 1           Brazil   vale da grama                   1300
# 2           Brazil  south of minas                   1250
# 3           Brazil  south of minas                   1250
# 4           Brazil  south of minas                   1200
#
#    Location.Altitude.Max  Location.Altitude.Average  Year Data.Owner  \
# 0                   1250                       1250  2011   nucoffee
# 1                   1300                       1300  2011   nucoffee
# 2                   1250                       1250  2011   nucoffee
# 3                   1250                       1250  2011   nucoffee
# 4                   1200                       1200  2011   nucoffee
#
#   Data.Type.Species Data.Type.Variety Data.Type.Processing method  ...  \
# 0           Arabica           Bourbon               Natural / Dry  ...
# 1           Arabica           Bourbon               Natural / Dry  ...
# 2           Arabica           Bourbon   Semi-washed / Semi-pulped  ...
# 3           Arabica           Bourbon   Semi-washed / Semi-pulped  ...
# 4           Arabica           Bourbon               Natural / Dry  ...
#
#    Data.Scores.Flavor  Data.Scores.Aftertaste  Data.Scores.Acidity  \
# 0                8.50                    8.00                 8.00
# 1                8.17                    8.00                 7.75
# 2                8.00                    8.00                 8.00
# 3                8.00                    8.00                 7.67
# 4                7.92                    7.75                 7.75
#
#    Data.Scores.Body  Data.Scores.Balance  Data.Scores.Uniformity  \
# 0              8.00                 8.00                    10.0
# 1              8.00                 8.00                    10.0
# 2              7.75                 8.00                    10.0
# 3              7.75                 8.00                    10.0
# 4              8.00                 7.75                    10.0
#
#    Data.Scores.Sweetness  Data.Scores.Moisture  Data.Scores.Total  Data.Color
# 0                   10.0                  0.12              86.92       Green
# 1                   10.0                  0.12              86.42       Green
# 2                   10.0                  0.11              86.08  Blue-Green
# 3                   10.0                  0.11              85.42  Blue-Green
# 4                   10.0                  0.11              84.92       Green
#
# [5 rows x 23 columns]

# %%
df.shape[0]
# Out:
# 582

# %% [markdown]
# ## 2. Research Goal and More Data Cleaning
#
# Suppose that we would like to *eventually* build a linear regression model that will predicts the `Aroma` of the coffee given the following explanatory variables:
# * `Aftertaste`
# * `Acidity`
# * `Body`
# * `Balance`
# * `Variety`
# * `Color`

# %% [markdown]
# ### 2.1. Dropping NaN Values
#
# 1. First create a dataframe that is comprised of just these 7 variables.
# 2. Then drop all rows from this dataframe with NaN values.
# 3. How many rows did you drop?

# %%
df = df[['Data.Scores.Aftertaste','Data.Scores.Acidity','Data.Scores.Body','Data.Scores.Balance','Data.Type.Variety','Data.Color', 'Data.Scores.Aroma']]
df
# Out:
#      Data.Scores.Aftertaste  Data.Scores.Acidity  Data.Scores.Body  \
# 0                      8.00                 8.00              8.00
# 1                      8.00                 7.75              8.00
# 2                      8.00                 8.00              7.75
# 3                      8.00                 7.67              7.75
# 4                      7.75                 7.75              8.00
# ..                      ...                  ...               ...
# 577                    6.92                 7.33              7.25
# 578                    7.33                 7.42              7.50
# 579                    6.75                 6.92              7.00
# 580                    7.42                 7.42              7.67
# 581                    0.00                 0.00              0.00
#
#      Data.Scores.Balance Data.Type.Variety  Data.Color  Data.Scores.Aroma
# 0                   8.00           Bourbon       Green               8.50
# 1                   8.00           Bourbon       Green               8.50
# 2                   8.00           Bourbon  Blue-Green               8.33
# 3                   8.00           Bourbon  Blue-Green               8.00
# 4                   7.75           Bourbon       Green               8.00
# ..                   ...               ...         ...                ...
# 577                 7.33           Bourbon       Green               7.33
# 578                 7.42           Bourbon       Green               7.33
# 579                 6.92            Catuai       Green               7.58
# 580                 7.67           Bourbon       Green               7.58
# 581                 0.00           Caturra       Green               0.00
#
# [582 rows x 7 columns]

# %%
df_new = df.dropna()
df_new
# Out:
#      Data.Scores.Aftertaste  Data.Scores.Acidity  Data.Scores.Body  \
# 0                      8.00                 8.00              8.00
# 1                      8.00                 7.75              8.00
# 2                      8.00                 8.00              7.75
# 3                      8.00                 7.67              7.75
# 4                      7.75                 7.75              8.00
# ..                      ...                  ...               ...
# 577                    6.92                 7.33              7.25
# 578                    7.33                 7.42              7.50
# 579                    6.75                 6.92              7.00
# 580                    7.42                 7.42              7.67
# 581                    0.00                 0.00              0.00
#
#      Data.Scores.Balance Data.Type.Variety  Data.Color  Data.Scores.Aroma
# 0                   8.00           Bourbon       Green               8.50
# 1                   8.00           Bourbon       Green               8.50
# 2                   8.00           Bourbon  Blue-Green               8.33
# 3                   8.00           Bourbon  Blue-Green               8.00
# 4                   7.75           Bourbon       Green               8.00
# ..                   ...               ...         ...                ...
# 577                 7.33           Bourbon       Green               7.33
# 578                 7.42           Bourbon       Green               7.33
# 579                 6.92            Catuai       Green               7.58
# 580                 7.67           Bourbon       Green               7.58
# 581                 0.00           Caturra       Green               0.00
#
# [547 rows x 7 columns]

# %%
df.shape[0] - df_new.shape[0]
# Out:
# 35

# %% [markdown]
# ### 2.2. Outlier Inspection (for the Presence of Single Variable Outliers)
#
# Create a boxplot for each of your numerical variables in this dataset.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
sns.boxplot(x = 'Data.Scores.Aftertaste', y = 'Data.Scores.Aroma', data = df_new)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(x = 'Data.Scores.Acidity', y = 'Data.Scores.Aroma', data = df_new)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(x = 'Data.Scores.Body', y = 'Data.Scores.Aroma', data = df_new)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.boxplot(x = 'Data.Scores.Balance', y = 'Data.Scores.Aroma', data = df_new)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### 2.3. Outlier Cleaning
#
# 1. If you see any outliers that are remarkably distinct from the rest of the other observations in any of these plots, drop them from the dataset.
# 2. How many new rows did you drop?

# %%
df_new = df_new[df_new['Data.Scores.Aroma'] >= 6].reset_index()

# %%
df_new
# Out:
#      index  Data.Scores.Aftertaste  Data.Scores.Acidity  Data.Scores.Body  \
# 0        0                    8.00                 8.00              8.00
# 1        1                    8.00                 7.75              8.00
# 2        2                    8.00                 8.00              7.75
# 3        3                    8.00                 7.67              7.75
# 4        4                    7.75                 7.75              8.00
# ..     ...                     ...                  ...               ...
# 540    576                    6.92                 7.08              7.42
# 541    577                    6.92                 7.33              7.25
# 542    578                    7.33                 7.42              7.50
# 543    579                    6.75                 6.92              7.00
# 544    580                    7.42                 7.42              7.67
#
#      Data.Scores.Balance Data.Type.Variety  Data.Color  Data.Scores.Aroma
# 0                   8.00           Bourbon       Green               8.50
# 1                   8.00           Bourbon       Green               8.50
# 2                   8.00           Bourbon  Blue-Green               8.33
# 3                   8.00           Bourbon  Blue-Green               8.00
# 4                   7.75           Bourbon       Green               8.00
# ..                   ...               ...         ...                ...
# 540                 7.17           Caturra       Green               7.33
# 541                 7.33           Bourbon       Green               7.33
# 542                 7.42           Bourbon       Green               7.33
# 543                 6.92            Catuai       Green               7.58
# 544                 7.67           Bourbon       Green               7.58
#
# [545 rows x 8 columns]

# %%
547-df_new.shape[0]
# Out:
# 2

# %% [markdown]
# ### 2.4. Outlier Inspection (for the Presence of Two Variable Outliers)
#
# Create a *single* figure that visualizes the relationship between all pairs of numerical variables in this dataset.
#
# *For full credit, your code should be no longer than 2 lines here.*

# %%
dfa = df_new[['Data.Scores.Aftertaste','Data.Scores.Acidity','Data.Scores.Body','Data.Scores.Balance', 'Data.Scores.Aroma']]
sns.pairplot(dfa)

# %% [markdown]
# ### 2.5. Outlier Cleaning
#
# 1. Drop all significant outliers that you see in your figure above.
# 2. How many new rows did you drop?

# %%
dfa = dfa[dfa['Data.Scores.Acidity'] > 6]
dfa.shape[0]
# Out:
# 544

# %%
df_new.shape[0] - dfa.shape[0]
# Out:
# 1

# %% [markdown]
# ### 2.6. Outlier Cleaning Pros and Cons
#
# 1. When thinking about our research goal, what is one potential reason for why we may want to clean the outliers from our dataset?
# 2. When thinking about our research goal, what is one potential reason for why we may NOT want to clean the outliers from our dataset?

# %% [markdown]
# 1. Outliers can greatly affect the mean and standard deviation of our dataset and may cause misleading results to occur
# 2. However, not including the outlier is ignoring a data value that (possibly) could still occur naturally which means the findings of our analysis cannot be fully generalized to the population we are researching.

# %% [markdown]
# ### 2.7. Suitability of the the Correlation
#
# After performing our outlier cleaning above, is the correlation a suitable metric for evaluating the strength of the pairwise numerical relationships shown above? Explain.

# %% [markdown]
# The correlation should be suitable since there is no longer an outlier to affect it meaning the strength the relationship between the pairs of numerical variables should be accurately reflected by it.

# %% [markdown]
# ## 3. Pre-Analysis Questions
#
# ### 3.1. Strongest Numerical Explanatory Variable  Relationship
#
# Which `numerical explanatory variable` has the STRONGEST relationship with our response variable `Aroma`? Explain.

# %%
dfa.corr()
# Out:
#                         Data.Scores.Aftertaste  Data.Scores.Acidity  \
# Data.Scores.Aftertaste                1.000000             0.687425
# Data.Scores.Acidity                   0.687425             1.000000
# Data.Scores.Body                      0.679730             0.627392
# Data.Scores.Balance                   0.788719             0.670943
# Data.Scores.Aroma                     0.701995             0.617894
#
#                         Data.Scores.Body  Data.Scores.Balance  \
# Data.Scores.Aftertaste          0.679730             0.788719
# Data.Scores.Acidity             0.627392             0.670943
# Data.Scores.Body                1.000000             0.679977
# Data.Scores.Balance             0.679977             1.000000
# Data.Scores.Aroma               0.585854             0.692300
#
#                         Data.Scores.Aroma
# Data.Scores.Aftertaste           0.701995
# Data.Scores.Acidity              0.617894
# Data.Scores.Body                 0.585854
# Data.Scores.Balance              0.692300
# Data.Scores.Aroma                1.000000

# %% [markdown]
# Aftertaste has the strongest relationship with Aroma because its correlation is the closest to 1 or -1

# %% [markdown]
# ### 3.2. Best Fit Line
#
# Create a single scatterplot showing the relationship between `Aroma` and this numerical explanatory variable that you selected in 3.1. Plot a best fit line over this scatterplot.

# %%
sns.lmplot(x = 'Data.Scores.Aftertaste',y = 'Data.Scores.Aroma', data = dfa)

# %% [markdown]
# ### 3.3. Strongest  Categorical Explanatory Variable Relationship
#
# 1. Which categorical explantory variable has the STRONGEST relationship with our response variable `Aroma`? Explain.
# 2. Do either of these categorical explanatory variables show STRONG relationships with our response variable `Aroma`? Explain.
#
# *Hint: There are two figures/visualizations that you should show to explain this*

# %%
sns.barplot(x = 'Data.Color', y = 'Data.Scores.Aroma',data = df_new)
# Out:
# <Axes: xlabel='Data.Color', ylabel='Data.Scores.Aroma'>

# %%
sns.barplot(x = 'Data.Type.Variety', y = 'Data.Scores.Aroma',data = df_new)
# Out:
# <Axes: xlabel='Data.Type.Variety', ylabel='Data.Scores.Aroma'>

# %% [markdown]
# Neither explanatory variable seems to have a strong relationship with Aroma as both of them have roughly equal Aroma scores across all the categories in their respective areas.

# %% [markdown]
# ### 3.4 Multicollinearity of the Numerical Explanatory Variables
#
# Do our explanatory variables exhibit what we described as "multicollinearity" in the Unit 2 notes? Explain.

# %%
pd.crosstab(df_new['Data.Color'],df_new['Data.Type.Variety'], normalize= 'index').plot.bar()
# Out:
# <Axes: xlabel='Data.Color'>

# %% [markdown]
# Multicollinearity may be a problem in this dataset as their appears to be a relationship between the type of coffee and its color.

# %% [markdown]
# ### 3.5. Association of the Categorical Explanatory Variables
#
# Is there an association between our two categorical explanatory variables? Use the appropriate visualization to discuss this.

# %%
pd.crosstab(df_new['Data.Color'],df_new['Data.Type.Variety'], normalize= 'index').plot.bar()
# Out:
# <Axes: xlabel='Data.Color'>

# %% [markdown]
# As per the visualization from 3.4 there does appear to be an association between Color and Variety Type of coffee. The Caturra type appears more frequently in Bluish-Green than in Green or Unknown. Catuai appears twice as frequently in Blue-Green than in Green and about 5 or 6 times as much as Unknown. Bourbon appears in Green twice as much as in Blue-Green. Finally, Typica appears over twice as much in Unknown as in Green or Blue-Green and almost 4 times as much as in Bluish-Green

# %% [markdown]
# ## 4. Searching for Interaction Effects
#
# In a linear regression model, we say that there is an **interaction** between how a `categorical explanatory variable` and a `numerical explanatory variable` **affect** the `numerical response variable` if the **slopes** of the best fit lines of the `numerical explanatory variable` and the `numerical response variable` change for different values of the `categorical explanatory variable`.
#
# 1. Is there an interaction between how `Variety` and `Aftertaste` affect `Aroma`?
# 2. Is there an interaction between how `Variety` and `Acidity` affect `Aroma`?
# 3. Is there an interaction between how `Variety` and `Body` affect `Aroma`?
# 4. Is there an interaction between how `Color` and `Aftertaste` affect `Aroma`?
# 5. Is there an interaction between how `Color` and `Acidity` affect `Aroma`?
# 6. Is there an interaction between how `Color` and `Body` affect `Aroma`?
#
# You should create and interpret 6 visualizations to help you answer this.

# %% [markdown]
# There does not appear to be a significant affect from either Variety or Color in regards to the relationship between Aroma and the other numerical variables. Although, there is a slight change in the slope of the regression line for Green color and Caturra Variety; however, this change does not initially appear significant and may not be altogether important (though it cannot be totally assumed).

# %%
df_new
# Out:
#      index  Data.Scores.Aftertaste  Data.Scores.Acidity  Data.Scores.Body  \
# 0        0                    8.00                 8.00              8.00
# 1        1                    8.00                 7.75              8.00
# 2        2                    8.00                 8.00              7.75
# 3        3                    8.00                 7.67              7.75
# 4        4                    7.75                 7.75              8.00
# ..     ...                     ...                  ...               ...
# 540    576                    6.92                 7.08              7.42
# 541    577                    6.92                 7.33              7.25
# 542    578                    7.33                 7.42              7.50
# 543    579                    6.75                 6.92              7.00
# 544    580                    7.42                 7.42              7.67
#
#      Data.Scores.Balance Data.Type.Variety  Data.Color  Data.Scores.Aroma
# 0                   8.00           Bourbon       Green               8.50
# 1                   8.00           Bourbon       Green               8.50
# 2                   8.00           Bourbon  Blue-Green               8.33
# 3                   8.00           Bourbon  Blue-Green               8.00
# 4                   7.75           Bourbon       Green               8.00
# ..                   ...               ...         ...                ...
# 540                 7.17           Caturra       Green               7.33
# 541                 7.33           Bourbon       Green               7.33
# 542                 7.42           Bourbon       Green               7.33
# 543                 6.92            Catuai       Green               7.58
# 544                 7.67           Bourbon       Green               7.58
#
# [545 rows x 8 columns]

# %%
sns.lmplot(x = 'Data.Scores.Aftertaste', y = 'Data.Scores.Aroma', hue = 'Data.Type.Variety', data = df_new)

# %% [markdown]
# All of the Variety Types have a positive relatively linear correlation between Aftertast and Aroma.

# %%
sns.lmplot(x = 'Data.Scores.Acidity', y = 'Data.Scores.Aroma', hue = 'Data.Type.Variety', data = df_new)

# %% [markdown]
# Aside from Caturra, all the Variety Types have relatively strong positive linear correlation between Acidity and Aroma. Caturra's correlation seems to be less positive than the others, however.

# %%
sns.lmplot(x = 'Data.Scores.Body', y = 'Data.Scores.Aroma', hue = 'Data.Type.Variety', data = df_new)

# %% [markdown]
# All of the Variety Types have a relatively positive, linear, strong correlation between Body and Aroma.

# %%
sns.lmplot(x = 'Data.Scores.Aftertaste', y = 'Data.Scores.Aroma', hue = 'Data.Color', data = df_new)

# %% [markdown]
# All of the colors have a similar positive, linear correlation between Aroma and Aftertaste.

# %%
sns.lmplot(x = 'Data.Scores.Acidity', y = 'Data.Scores.Aroma', hue = 'Data.Color', data = df_new)

# %% [markdown]
# All the Colors have a similar positive, linear correlation between Acidity and Aroma. Although Green has more outliers than the other categories.

# %%
sns.lmplot(x = 'Data.Scores.Body', y = 'Data.Scores.Aroma', hue = 'Data.Color', data = df_new)

# %% [markdown]
# All of the Colors have a similiarly positive, linear correlation between body and Aroma. However their seem to be more outliers for Green than the other colors.
