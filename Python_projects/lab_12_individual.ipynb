# %% [markdown]
# # STAT 207 Lab Assignment 12 - Individual Part - [21 Points]
#
#
#
# ## <u>Case Study</u>: Classifying Airbnb Superhost Status
#
# Suppose that you have a spare room in your house (in Seattle) and you are considering advertising this room to guests on Airbnb. Airbnb superhosts are considered to be experienced hosts who provide a shining example for other hosts, and extraordinary experiences for their guests. Once a host reaches Superhost status, a superhost badge will automatically appear on their listing and profile to help guests identify them. You would like to assess your chances of being named a superhost with your property.
#
# The following dataset is a sample (assume random) of available Airbnb listings in Seattle, WA. These listings were collected in January 2016, and filtered to just contain listings from the five most popular Seattlbe neighborhoods (for Airbnb listings) and just contain listings that are either in a house or apartment property.
#
# This dataset contains the following variables.
#
# **Listing Information**
# The dataset contains the following information about the Airbnb *listing*:
# * <u>price</u>: price of the listing (per night)(in US dollars)
# * <u>review_scores_rating</u>: the average rating of the listing [0,100] (100 is the best)
# * <u>number_of_reviews</u>: the number of reviews for the listing
# * <u>security_deposit</u>: the security deposit required for the listing (in US dollars)
# * <u>cleaning_fee</u>: the cleaning fee required for the listing (in US dollars)
# * <u>neighborhood</u>: the neighborhood of Seattle the listing is located in
# * <u>property_type</u>: is the listing in a 'House' or 'Apartment'
# * <u>room_type</u>: is the listing a 'Entire home/apt', 'Private room', or 'Shared room'
# * <u>accommodates</u>: how many guests will the listing accommodate
# * <u>bathrooms</u>:how many bathrooms does the listing have
# * <u>beds</u>: how many beds does the listing have
#
# **Host Information**
# The dataset also contains the following information about the *host* of the given Airbnb listing:
# * <u>host_is_superhost</u>: is the host a "superhost": t=True, f=False
# * <u>host_has_profile_pic</u>: does the host have a profile pic in their bio: t=True, f=False
# * <u>host_response_time</u>: how fast will the host respond to requests (on average)
#
# ## Research Goals
#
# ### Primary Research Goal
# The primary research goal that we will pursue in this lab will be to build a predictive model that effectively predicts the `probability a Seattle Airbnb host is a **superhost**` for *new Seattle Airbnb listings/hosts* given some combination of the `remaining explanatory variables`.
#
# ### Secondary Research Goal
#
# Ideally, we would also like to interpret our final model.
#
#
#
# ## Points
#
# <p>&nbsp;</p>
# <table style="border: none;border-collapse: collapse;width:102pt;">
#     <tbody>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;width:51pt;">Problem</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:700;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:general;vertical-align:bottom;border:.5pt solid windowtext;border-left:none;width:51pt;">Points</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.25</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.25</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">0.5</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">1.4.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">2</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">2.4</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">3.5</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">2</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">2</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">4.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.1</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.2</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.3</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#         <tr>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;height:14.25pt;border-top:none;">5.4</td>
#             <td style="padding:0px;color:black;font-size:15px;font-weight:400;font-style:normal;text-decoration:none;font-family:Calibri, sans-serif;text-align:right;vertical-align:bottom;border:.5pt solid windowtext;border-top:none;border-left:none;">1</td>
#         </tr>
#     </tbody>
# </table>

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score

# %% [markdown]
# ## 1. Basic Data Examination and Cleaning
#
# ### 1.1. Reading the Dataset
#
# 1. Read the `seattle_airbnb_listings.csv` file into a dataframe.
#
# 2. Display your dataframe.
#
# 3. Show how many rows your dataframe has.

# %%
df = pd.read_csv('seattle_airbnb_listings.csv')

# %%
df
# Out:
#      price  review_scores_rating  number_of_reviews  security_deposit  \
# 0      300                   100                 24               500
# 1      149                    96                 11               300
# 2       95                    95                 79               150
# 3      105                   100                 13               500
# 4      140                    99                 30               250
# ..     ...                   ...                ...               ...
# 320    400                   100                  4               200
# 321    225                    95                  8               200
# 322    350                    94                 20               350
# 323    150                    88                  8               250
# 324     99                    96                 35               100
#
#      cleaning_fee neighborhood property_type        room_type  accommodates  \
# 0              95  Wallingford         House  Entire home/apt             5
# 1             105  Wallingford     Apartment  Entire home/apt             6
# 2              40  Wallingford     Apartment  Entire home/apt             3
# 3              50  Wallingford         House     Private room             2
# 4              65  Wallingford         House  Entire home/apt             2
# ..            ...          ...           ...              ...           ...
# 320           125      Fremont         House  Entire home/apt             8
# 321           100      Fremont         House  Entire home/apt             4
# 322           175      Fremont         House  Entire home/apt             6
# 323           105      Fremont     Apartment  Entire home/apt             6
# 324            67      Fremont     Apartment  Entire home/apt             2
#
#      bathrooms  beds  host_response_time  host_response_rate  \
# 0          1.5     3  within a few hours                1.00
# 1          1.0     3      within an hour                1.00
# 2          1.0     2      within an hour                1.00
# 3          2.0     1  within a few hours                1.00
# 4          1.0     1      within an hour                1.00
# ..         ...   ...                 ...                 ...
# 320        2.5     3      within an hour                1.00
# 321        1.0     2  within a few hours                1.00
# 322        2.5     4  within a few hours                1.00
# 323        1.0     3  within a few hours                0.90
# 324        1.0     1  within a few hours                0.67
#
#     host_is_superhost host_has_profile_pic host_identity_verified
# 0                   t                    t                      t
# 1                   f                    t                      t
# 2                   f                    t                      t
# 3                   t                    t                      t
# 4                   t                    t                      t
# ..                ...                  ...                    ...
# 320                 t                    t                      t
# 321                 f                    t                      t
# 322                 f                    t                      t
# 323                 f                    t                      f
# 324                 f                    t                      t
#
# [325 rows x 16 columns]

# %%
df.shape[0]
# Out:
# 325

# %% [markdown]
# ### 1.2. 0/1 Response Variable
#
# Create a new 0/1 variable in your dataset in which `superhosts=1` and `nonsuperhosts=0`.

# %%
df['superhost'] = df['host_is_superhost'].replace({'t':1,'f':0})
df
# Out:
#      price  review_scores_rating  number_of_reviews  security_deposit  \
# 0      300                   100                 24               500
# 1      149                    96                 11               300
# 2       95                    95                 79               150
# 3      105                   100                 13               500
# 4      140                    99                 30               250
# ..     ...                   ...                ...               ...
# 320    400                   100                  4               200
# 321    225                    95                  8               200
# 322    350                    94                 20               350
# 323    150                    88                  8               250
# 324     99                    96                 35               100
#
#      cleaning_fee neighborhood property_type        room_type  accommodates  \
# 0              95  Wallingford         House  Entire home/apt             5
# 1             105  Wallingford     Apartment  Entire home/apt             6
# 2              40  Wallingford     Apartment  Entire home/apt             3
# 3              50  Wallingford         House     Private room             2
# 4              65  Wallingford         House  Entire home/apt             2
# ..            ...          ...           ...              ...           ...
# 320           125      Fremont         House  Entire home/apt             8
# 321           100      Fremont         House  Entire home/apt             4
# 322           175      Fremont         House  Entire home/apt             6
# 323           105      Fremont     Apartment  Entire home/apt             6
# 324            67      Fremont     Apartment  Entire home/apt             2
#
#      bathrooms  beds  host_response_time  host_response_rate  \
# 0          1.5     3  within a few hours                1.00
# 1          1.0     3      within an hour                1.00
# 2          1.0     2      within an hour                1.00
# 3          2.0     1  within a few hours                1.00
# 4          1.0     1      within an hour                1.00
# ..         ...   ...                 ...                 ...
# 320        2.5     3      within an hour                1.00
# 321        1.0     2  within a few hours                1.00
# 322        2.5     4  within a few hours                1.00
# 323        1.0     3  within a few hours                0.90
# 324        1.0     1  within a few hours                0.67
#
#     host_is_superhost host_has_profile_pic host_identity_verified  superhost
# 0                   t                    t                      t          1
# 1                   f                    t                      t          0
# 2                   f                    t                      t          0
# 3                   t                    t                      t          1
# 4                   t                    t                      t          1
# ..                ...                  ...                    ...        ...
# 320                 t                    t                      t          1
# 321                 f                    t                      t          0
# 322                 f                    t                      t          0
# 323                 f                    t                      f          0
# 324                 f                    t                      t          0
#
# [325 rows x 17 columns]

# %% [markdown]
# ### 1.3. Train-Test-Split
#
# Create a training dataset and a test dataset from your dataframe using a random state of `101` and a test dataset size that is a random sample of about 20% of the observations from the original dataset.

# %%
df_train, df_test = train_test_split(df, test_size=.2, random_state=101)

# %%
print(df_train.shape[0]/df.shape[0])
print(df_test.shape[0]/df.shape[0])
# Out:
# 0.8
# 0.2

# %% [markdown]
# ### 1.4. Numerical Explanatory Variable Scaling
#
# #### 1.4.1. Numerical Explanatory Variable Standard Deviations
#
# First, calculate the standard deviation of each of your numerical explanatory variables in your training dataset.

# %%
num_exp = df_train[['price','review_scores_rating','number_of_reviews','security_deposit','cleaning_fee','accommodates','bathrooms','beds','host_response_rate']]
num_exp.std()
# Out:
# price                   101.299444
# review_scores_rating      7.588386
# number_of_reviews        37.481854
# security_deposit        292.636226
# cleaning_fee             44.885429
# accommodates              2.087238
# bathrooms                 0.586867
# beds                      1.177429
# host_response_rate        0.098958
# dtype: float64

# %% [markdown]
# #### 1.4.2. Scaling the Numerical Explanatory Variables in the Training Dataset
#
# Just like we saw in a linear regression model, if the standard deviations of the numerical explanatory variables in a logistic regression model are not all roughly equal, then we cannot interpret the magnitude of the slopes as reflecting the predictive power that the corresponding variable brings to the model.
#
# Because we'd now like to (ideally) interpret the slope magnitudes of our model in this way, z-score scale the numerical explanatory variables in your training dataset (using the TRAINING dataset means and standard deviations.)

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(num_exp)
df_scaled = pd.DataFrame(scaled, columns=num_exp.columns)
df_scaled.std()
# Out:
# price                   1.001929
# review_scores_rating    1.001929
# number_of_reviews       1.001929
# security_deposit        1.001929
# cleaning_fee            1.001929
# accommodates            1.001929
# bathrooms               1.001929
# beds                    1.001929
# host_response_rate      1.001929
# dtype: float64

# %% [markdown]
# #### 1.4.3. Scaling the Numerical Explanatory Variables in the Test Dataset
#
# Then, z-score scale the numerical explanatory variables in your TEST dataset (using the means and standard deviations from the TRAINING dataset).

# %%
num_exp_test = df_test[['price','review_scores_rating','number_of_reviews','security_deposit','cleaning_fee','accommodates','bathrooms','beds','host_response_rate']]
scaled2 = scaler.fit_transform(num_exp_test)
df_scaled_test = pd.DataFrame(scaled2, columns=num_exp_test.columns)
df_scaled_test.std()
# Out:
# price                   1.007782
# review_scores_rating    1.007782
# number_of_reviews       1.007782
# security_deposit        1.007782
# cleaning_fee            1.007782
# accommodates            1.007782
# bathrooms               1.007782
# beds                    1.007782
# host_response_rate      1.007782
# dtype: float64

# %% [markdown]
# ## 2. Full Model Classification
#
# ### 2.1. Full Logistic Regression Model
#
# First, let's fit the "full" model logistic regression model with our training dataset. In the interest of time, we'll call our "full" model the one that predicts the `probability that a host is a superhost` given the four explanatory variables below:
# * `review_scores_rating`
# * `number_of_reviews`
# * `neighborhood`
# * `room_type`
#
#
# Show the summary output table for this logistic regression model.

# %%
full_model = smf.logit(formula='superhost~review_scores_rating+number_of_reviews+neighborhood+room_type', data=df_train).fit()
full_model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.478540
#          Iterations: 35
# C:\Users\diamo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              superhost   No. Observations:                  260
# Model:                          Logit   Df Residuals:                      251
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 16 Apr 2024   Pseudo R-squ.:                  0.2080
# Time:                        20:57:37   Log-Likelihood:                -124.42
# converged:                      False   LL-Null:                       -157.09
# Covariance Type:            nonrobust   LLR p-value:                 4.122e-11
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     -25.9833      6.071     -4.280      0.000     -37.883     -14.084
# neighborhood[T.Broadway]       -1.1219      0.446     -2.516      0.012      -1.996      -0.248
# neighborhood[T.Fremont]        -0.8328      0.588     -1.417      0.157      -1.985       0.319
# neighborhood[T.Minor]          -0.1591      0.484     -0.329      0.742      -1.108       0.789
# neighborhood[T.Wallingford]    -0.7314      0.501     -1.461      0.144      -1.712       0.250
# room_type[T.Private room]       0.0568      0.428      0.133      0.895      -0.783       0.897
# room_type[T.Shared room]      -24.3619   9.11e+04     -0.000      1.000   -1.78e+05    1.78e+05
# review_scores_rating            0.2634      0.062      4.247      0.000       0.142       0.385
# number_of_reviews               0.0148      0.005      3.209      0.001       0.006       0.024
# ===============================================================================================
# """

# %% [markdown]
# ### 2.2. Test Dataset ROC Curve
#
# Now, create an ROC curve for this logistic regression model and the **test dataset**. Also calculate the AUC of this ROC curve.

# %%
df_test['predictive_prob'] = full_model.predict(df_test[['review_scores_rating','number_of_reviews','neighborhood','room_type']])

# %%
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=df_test['predictive_prob'])

# %%
A = pd.DataFrame({'fpr':fprs, 'tpr': tprs})

# %%
auc = roc_auc_score(y_true=df_test['superhost'], y_score=df_test['predictive_prob'])

# %%
def plot_roc(fpr, tpr, auc, lw=2):
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label = "ROC curve (area = " +str(round(auc,3)) + ')')
    plt.plot([0, 1], [0, 1], color= 'navy', lw=lw, linestyle = '--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.show()
plot_roc(fprs, tprs, auc)

# %% [markdown]
# ### 2.3. Interpreting the Test ROC and AUC
#
# 1. Suppose we were to use the full logistic regression model to classify the observations in the test dataset. Does there exist a predictive probability threshold that we could use that would create a classification of the test dataset with close to perfect FPR and TPR? Explain.
# 2. Evaluate how well the full logistic regression model would do in general when it comes to classifying the test dataset.

# %% [markdown]
# 1) The relationship between the FPR and TPR is nearly linear in nature (positively linear) which means there are no values that have a nearly perfect FPR and TPR.
# 2) The full logistic regression model would do badly classifying the test dataset because the area of the roc curve is not very close to 1

# %% [markdown]
# ### 2.4. Evaluating the Full Logistic Regression Model with Respect to the Primary Research Goal
#
# Based on our analysis above, how well might the full logistic regression model do when it comes to classifying *new Airbnb hosts* as either a super host or not a superhost? Explain.

# %% [markdown]
# The full logistic regression model would do very badly classifying new Airbnb hosts as either a superhost or not because the AUC is roughly .5 meaning the model is essentially guessing at random whether or not a host is a superhost.

# %% [markdown]
# ## 3. Backwards Elimination
#
# Now let's suppose we would like to try to find the logistic regression model that will yield the **highest test dataset AUC**. Use a backwards elimination algorithm to search for the logistic regression model that will yield the **highest test dataset AUC**.

# %%
df_train
# Out:
#      price  review_scores_rating  number_of_reviews  security_deposit  \
# 119    130                    20                  1               200
# 158    115                    93                 37               150
# 247    138                    94                 96               100
# 200     79                    72                 10               350
# 198    150                   100                  3               700
# ..     ...                   ...                ...               ...
# 40     175                    95                  4               100
# 75      72                    98                 94               150
# 87     108                   100                  8               120
# 63      40                   100                  1               350
# 11     135                    97                 71               200
#
#      cleaning_fee neighborhood property_type        room_type  accommodates  \
# 119            61     Belltown     Apartment  Entire home/apt             2
# 158            45     Belltown     Apartment  Entire home/apt             3
# 247            50     Broadway     Apartment  Entire home/apt             2
# 200            35     Broadway         House     Private room             2
# 198           100     Broadway     Apartment  Entire home/apt             4
# ..            ...          ...           ...              ...           ...
# 40             75  Wallingford         House  Entire home/apt             4
# 75             30        Minor         House     Private room             2
# 87             25        Minor         House     Private room             2
# 63             35  Wallingford         House      Shared room             1
# 11             30  Wallingford     Apartment  Entire home/apt             6
#
#      bathrooms  beds  host_response_time  host_response_rate  \
# 119        1.0     1      within an hour                1.00
# 158        1.0     2      within an hour                1.00
# 247        1.0     1  within a few hours                0.53
# 200        0.5     1      within an hour                0.90
# 198        1.0     1  a few days or more                0.25
# ..         ...   ...                 ...                 ...
# 40         1.0     1      within an hour                1.00
# 75         1.5     1        within a day                0.75
# 87         1.0     2      within an hour                0.83
# 63         1.0     1      within an hour                0.90
# 11         1.0     3  within a few hours                0.90
#
#     host_is_superhost host_has_profile_pic host_identity_verified  superhost
# 119                 f                    t                      f          0
# 158                 f                    t                      t          0
# 247                 f                    t                      t          0
# 200                 f                    t                      t          0
# 198                 f                    t                      t          0
# ..                ...                  ...                    ...        ...
# 40                  f                    t                      t          0
# 75                  t                    t                      t          1
# 87                  t                    t                      t          1
# 63                  f                    t                      t          0
# 11                  t                    t                      t          1
#
# [260 rows x 17 columns]

# %%
elim_review_scores = smf.logit(formula='superhost~number_of_reviews+neighborhood+room_type', data=df_train).fit()
df_test['predictive_prob_elim_review_scores'] = elim_review_scores.predict(df_test[['number_of_reviews','neighborhood','room_type']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_review_scores'])
auc = roc_auc_score(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_review_scores'])
plot_roc(fprs, tprs, auc)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.534945
#          Iterations: 35
# C:\Users\diamo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
elim_num_reviews = smf.logit(formula='superhost~review_scores_rating+neighborhood+room_type', data=df_train).fit()
df_test['predictive_prob_elim_num_reviews'] = elim_num_reviews.predict(df_test[['review_scores_rating','neighborhood','room_type']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_num_reviews'])
auc = roc_auc_score(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_num_reviews'])
plot_roc(fprs, tprs, auc)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.498659
#          Iterations: 35
# C:\Users\diamo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
elim_neighborhood = smf.logit(formula='superhost~number_of_reviews+review_scores_rating+room_type', data=df_train).fit()
df_test['predictive_prob_elim_neighborhood'] = elim_neighborhood.predict(df_test[['number_of_reviews','review_scores_rating','room_type']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_neighborhood'])
auc = roc_auc_score(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_neighborhood'])
plot_roc(fprs, tprs, auc)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.495466
#          Iterations: 35
# C:\Users\diamo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
elim_room = smf.logit(formula='superhost~number_of_reviews+neighborhood+review_scores_rating', data=df_train).fit()
df_test['predictive_prob_elim_room'] = elim_room.predict(df_test[['number_of_reviews','neighborhood','review_scores_rating']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_room'])
auc = roc_auc_score(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_room'])
plot_roc(fprs, tprs, auc)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.491302
#          Iterations 8

# %%
elim_review_scores_and_num = smf.logit(formula='superhost~neighborhood+room_type', data=df_train).fit()
#elim_review_scores_and_num.predict(df_test[['neighborhood','room_type']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=elim_review_scores_and_num.predict(df_test[['neighborhood','room_type']]))
auc = roc_auc_score(y_true=df_test['superhost'], y_score=elim_review_scores_and_num.predict(df_test[['neighborhood','room_type']]))
plot_roc(fprs, tprs, auc)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.541226
#          Iterations: 35
# C:\Users\diamo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
elim_review_scores_and_neighborhood = smf.logit(formula='superhost~number_of_reviews+room_type', data=df_train).fit()
#elim_review_scores_and_neighborhood.predict(df_test[['number_of_reviews','room_type']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=elim_review_scores_and_neighborhood.predict(df_test[['number_of_reviews','room_type']]))
auc = roc_auc_score(y_true=df_test['superhost'], y_score=elim_review_scores_and_neighborhood.predict(df_test[['number_of_reviews','room_type']]))
plot_roc(fprs, tprs, auc)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.568409
#          Iterations: 35
# C:\Users\diamo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
elim_review_scores_and_room = smf.logit(formula='superhost~number_of_reviews+neighborhood', data=df_train).fit()
#elim_review_scores_and_room.predict(df_test[['number_of_reviews','neighborhood']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=elim_review_scores_and_room.predict(df_test[['number_of_reviews','neighborhood']]))
auc = roc_auc_score(y_true=df_test['superhost'], y_score=elim_review_scores_and_room.predict(df_test[['number_of_reviews','neighborhood']]))
plot_roc(fprs, tprs, auc)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.555231
#          Iterations 5

# %%
elim_num_reviews_and_neighborhood = smf.logit(formula='superhost~review_scores_rating+room_type', data=df_train).fit()
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=elim_num_reviews_and_neighborhood.predict(df_test[['review_scores_rating','room_type']]))
auc = roc_auc_score(y_true=df_test['superhost'], y_score=elim_num_reviews_and_neighborhood.predict(df_test[['review_scores_rating','room_type']]))
plot_roc(fprs, tprs, auc)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.514905
#          Iterations: 35
# C:\Users\diamo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
elim_num_reviews_and_room = smf.logit(formula='superhost~review_scores_rating+neighborhood', data=df_train).fit()
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=elim_num_reviews_and_room.predict(df_test[['review_scores_rating','neighborhood']]))
auc = roc_auc_score(y_true=df_test['superhost'], y_score=elim_num_reviews_and_room.predict(df_test[['review_scores_rating','neighborhood']]))
plot_roc(fprs, tprs, auc)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.516803
#          Iterations 7

# %%
elim_neighborhood_and_room = smf.logit(formula='superhost~review_scores_rating+number_of_reviews', data=df_train).fit()
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=elim_neighborhood_and_room.predict(df_test[['review_scores_rating','number_of_reviews']]))
auc = roc_auc_score(y_true=df_test['superhost'], y_score=elim_neighborhood_and_room.predict(df_test[['review_scores_rating','number_of_reviews']]))
plot_roc(fprs, tprs, auc)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.510512
#          Iterations 8

# %% [markdown]
# ## 4. Selecting the Best Final Model Classification
#
# Now, we would like to use our final logistic regression model that we selected in #3 to create a classification that best meets our research goals.
#
# ### 4.1. Test ROC and AUC
#
# Plot the ROC curve for this final logistic regression model and the test dataset.

# %%
elim_room = smf.logit(formula='superhost~number_of_reviews+neighborhood+review_scores_rating', data=df_train).fit()
df_test['predictive_prob_elim_room'] = elim_room.predict(df_test[['number_of_reviews','neighborhood','review_scores_rating']])
fprs, tprs, thresholds = roc_curve(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_room'])
auc = roc_auc_score(y_true=df_test['superhost'], y_score=df_test['predictive_prob_elim_room'])
plot_roc(fprs, tprs, auc)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.491302
#          Iterations 8

# %% [markdown]
# ### 4.2. Specific Classifier Use Case
#
# Suppose that you work as a data scientist at Airbnb and you would like to design a new automated algorithm which predicts whether or not an Airbnb listing host is deserving of an Superhost status (based on the observations in this dataset). To keep existing superhosts happy, you would **ideally like for as many of the people in this dataset who are already superhosts to be awarded (ie. predicted) to be a superhost**. On the other hand, suppose that your boss has decided that **at most 20% of nonsuperhosts should be expected to be misclassified as a superhost in new datasets.**
#
# Practically speaking you'd be classifying hosts as superhosts vs. nonsuperhosts for *new datasets*.
#
# 1. If we were to use the final logistic regression from #3, what predictive probability threshold should we use to create a classification that best meets these specific research goals and specifications?
# 2. What false positive rate and true positive rate would the test dataset classification have if we were to use this predictive probability threshold?

# %%
def fpr_tpr_thresh(y, pred_prob, thresh):
    yhat = 1*(pred_prob >= thresh)
    tn, fp, fn , tp = confusion_matrix(y_true=y, y_pred=yhat).ravel()
    tpr = tp/(fn+tp)
    fpr= fp/(fp+tn)
    return pd.DataFrame({'threshold': [thresh], 'fpr':[fpr], 'tpr':[tpr]})

# %%
for thresh in np.arange(0,1.01,.01):
    print(fpr_tpr_thresh(df_test['superhost'], df_test['predictive_prob_elim_room'], thresh))
# Out:
#    threshold  fpr  tpr
# 0        0.0  1.0  1.0
#    threshold       fpr  tpr
# 0       0.01  0.911111  1.0
#    threshold       fpr  tpr
# 0       0.02  0.911111  1.0
#    threshold       fpr  tpr
# 0       0.03  0.844444  1.0
#    threshold       fpr  tpr
# 0       0.04  0.822222  1.0
#    threshold       fpr  tpr
# 0       0.05  0.755556  1.0
#    threshold       fpr   tpr
# 0       0.06  0.755556  0.95
#    threshold       fpr   tpr
# 0       0.07  0.755556  0.95
#    threshold       fpr   tpr
# 0       0.08  0.755556  0.95
#    threshold       fpr   tpr
# 0       0.09  0.755556  0.95
#    threshold       fpr   tpr
# 0        0.1  0.733333  0.95
#    threshold       fpr   tpr
# 0       0.11  0.711111  0.95
#    threshold       fpr   tpr
# 0       0.12  0.711111  0.95
#    threshold       fpr   tpr
# 0       0.13  0.644444  0.95
#    threshold  fpr  tpr
# 0       0.14  0.6  0.9
#    threshold       fpr  tpr
# 0       0.15  0.577778  0.9
#    threshold       fpr  tpr
# 0       0.16  0.555556  0.9
#    threshold       fpr  tpr
# 0       0.17  0.555556  0.9
#    threshold       fpr  tpr
# 0       0.18  0.488889  0.9
#    threshold       fpr  tpr
# 0       0.19  0.466667  0.9
#    threshold       fpr   tpr
# 0        0.2  0.444444  0.85
#    threshold       fpr   tpr
# 0       0.21  0.444444  0.85
#    threshold       fpr  tpr
# 0       0.22  0.444444  0.8
#    threshold       fpr  tpr
# 0       0.23  0.444444  0.8
#    threshold       fpr  tpr
# 0       0.24  0.444444  0.8
#    threshold  fpr  tpr
# 0       0.25  0.4  0.8
#    threshold       fpr  tpr
# 0       0.26  0.377778  0.8
#    threshold       fpr  tpr
# 0       0.27  0.355556  0.8
#    threshold       fpr  tpr
# 0       0.28  0.355556  0.8
#    threshold       fpr   tpr
# 0       0.29  0.333333  0.75
#    threshold       fpr   tpr
# 0        0.3  0.333333  0.75
#    threshold       fpr   tpr
# 0       0.31  0.266667  0.75
#    threshold       fpr   tpr
# 0       0.32  0.244444  0.75
#    threshold  fpr   tpr
# 0       0.33  0.2  0.75
#    threshold  fpr  tpr
# 0       0.34  0.2  0.7
#    threshold  fpr  tpr
# 0       0.35  0.2  0.7
#    threshold  fpr  tpr
# 0       0.36  0.2  0.7
#    threshold       fpr  tpr
# 0       0.37  0.177778  0.7
#    threshold       fpr  tpr
# 0       0.38  0.177778  0.7
#    threshold       fpr  tpr
# 0       0.39  0.155556  0.7
#    threshold       fpr   tpr
# 0        0.4  0.155556  0.65
#    threshold       fpr   tpr
# 0       0.41  0.155556  0.55
#    threshold       fpr   tpr
# 0       0.42  0.133333  0.55
#    threshold       fpr   tpr
# 0       0.43  0.133333  0.55
#    threshold       fpr  tpr
# 0       0.44  0.133333  0.5
#    threshold       fpr   tpr
# 0       0.45  0.133333  0.45
#    threshold       fpr   tpr
# 0       0.46  0.111111  0.45
#    threshold       fpr  tpr
# 0       0.47  0.111111  0.4
#    threshold       fpr  tpr
# 0       0.48  0.111111  0.4
#    threshold       fpr  tpr
# 0       0.49  0.111111  0.4
#    threshold       fpr  tpr
# 0        0.5  0.111111  0.4
#    threshold       fpr  tpr
# 0       0.51  0.111111  0.3
#    threshold       fpr  tpr
# 0       0.52  0.111111  0.3
#    threshold       fpr  tpr
# 0       0.53  0.111111  0.3
#    threshold       fpr  tpr
# 0       0.54  0.088889  0.3
#    threshold       fpr  tpr
# 0       0.55  0.088889  0.3
#    threshold       fpr  tpr
# 0       0.56  0.066667  0.3
#    threshold       fpr   tpr
# 0       0.57  0.044444  0.15
#    threshold       fpr  tpr
# 0       0.58  0.022222  0.1
#    threshold       fpr   tpr
# 0       0.59  0.022222  0.05
#    threshold       fpr   tpr
# 0        0.6  0.022222  0.05
#    threshold       fpr   tpr
# 0       0.61  0.022222  0.05
#    threshold  fpr   tpr
# 0       0.62  0.0  0.05
#    threshold  fpr   tpr
# 0       0.63  0.0  0.05
#    threshold  fpr   tpr
# 0       0.64  0.0  0.05
#    threshold  fpr   tpr
# 0       0.65  0.0  0.05
#    threshold  fpr   tpr
# 0       0.66  0.0  0.05
#    threshold  fpr   tpr
# 0       0.67  0.0  0.05
#    threshold  fpr   tpr
# 0       0.68  0.0  0.05
#    threshold  fpr   tpr
# 0       0.69  0.0  0.05
#    threshold  fpr   tpr
# 0        0.7  0.0  0.05
#    threshold  fpr   tpr
# 0       0.71  0.0  0.05
#    threshold  fpr   tpr
# 0       0.72  0.0  0.05
#    threshold  fpr   tpr
# 0       0.73  0.0  0.05
#    threshold  fpr   tpr
# 0       0.74  0.0  0.05
#    threshold  fpr   tpr
# 0       0.75  0.0  0.05
#    threshold  fpr   tpr
# 0       0.76  0.0  0.05
#    threshold  fpr  tpr
# 0       0.77  0.0  0.0
#    threshold  fpr  tpr
# 0       0.78  0.0  0.0
#    threshold  fpr  tpr
# 0       0.79  0.0  0.0
#    threshold  fpr  tpr
# 0        0.8  0.0  0.0
#    threshold  fpr  tpr
# 0       0.81  0.0  0.0
#    threshold  fpr  tpr
# 0       0.82  0.0  0.0
#    threshold  fpr  tpr
# 0       0.83  0.0  0.0
#    threshold  fpr  tpr
# 0       0.84  0.0  0.0
#    threshold  fpr  tpr
# 0       0.85  0.0  0.0
#    threshold  fpr  tpr
# 0       0.86  0.0  0.0
#    threshold  fpr  tpr
# 0       0.87  0.0  0.0
#    threshold  fpr  tpr
# 0       0.88  0.0  0.0
#    threshold  fpr  tpr
# 0       0.89  0.0  0.0
#    threshold  fpr  tpr
# 0        0.9  0.0  0.0
#    threshold  fpr  tpr
# 0       0.91  0.0  0.0
#    threshold  fpr  tpr
# 0       0.92  0.0  0.0
#    threshold  fpr  tpr
# 0       0.93  0.0  0.0
#    threshold  fpr  tpr
# 0       0.94  0.0  0.0
#    threshold  fpr  tpr
# 0       0.95  0.0  0.0
#    threshold  fpr  tpr
# 0       0.96  0.0  0.0
#    threshold  fpr  tpr
# 0       0.97  0.0  0.0
#    threshold  fpr  tpr
# 0       0.98  0.0  0.0
#    threshold  fpr  tpr
# 0       0.99  0.0  0.0
#    threshold  fpr  tpr
# 0        1.0  0.0  0.0

# %% [markdown]
# A predictive probability of .33 would work the best since it meets the "at most 20%" fpr requirement and has the highest tpr for any fpr <= .2.

# %% [markdown]
# ### 4.3. Specificity and Sensitivity
#
# What is the specificity and sensitivity of the test dataset classification that you selected in #4.2?

# %% [markdown]
# The specificity is .8 and the sensitivity is .75.

# %% [markdown]
# ## 5. Interpreting the Final Logistic Regression Model
#
# Finally, let's interpret the final logistic regression model selected in #3.
#
# ### 5.1. Logistic Regression Equation
#
# First, put this final model into a logistic regression equation. Your equation should have the predictive probability on the left hand side. Make sure to use appropriate notation discussed in class.

# %%
elim_room.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              superhost   No. Observations:                  260
# Model:                          Logit   Df Residuals:                      253
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 16 Apr 2024   Pseudo R-squ.:                  0.1869
# Time:                        21:23:37   Log-Likelihood:                -127.74
# converged:                       True   LL-Null:                       -157.09
# Covariance Type:            nonrobust   LLR p-value:                 8.228e-11
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     -26.6564      5.856     -4.552      0.000     -38.135     -15.178
# neighborhood[T.Broadway]       -1.1255      0.428     -2.629      0.009      -1.965      -0.286
# neighborhood[T.Fremont]        -0.7605      0.586     -1.297      0.195      -1.910       0.389
# neighborhood[T.Minor]          -0.0800      0.466     -0.172      0.864      -0.992       0.832
# neighborhood[T.Wallingford]    -0.8508      0.485     -1.752      0.080      -1.802       0.101
# number_of_reviews               0.0163      0.005      3.587      0.000       0.007       0.025
# review_scores_rating            0.2692      0.060      4.506      0.000       0.152       0.386
# ===============================================================================================
# """

# %% [markdown]
# p^ = 1/(1 + e^-(-26.6564 - 1.1255(neighborhood[T.Broadway]) - 0.7605(neighborhood[T.Fremont]) - 0.0800(neighborhood[T.Minor]) - 0.8508(neighborhood[T.Wallingford]) + 0.0163(number_of_reviews) + 0.2692(review_scores_rating)))

# %% [markdown]
# ### 5.2. Final Model Multicollinearity
#
# Does your final model have an issue with multicollinearity? Explain.

# %%
df_train[['number_of_reviews','review_scores_rating']].corr()
# Out:
#                       number_of_reviews  review_scores_rating
# number_of_reviews              1.000000             -0.001425
# review_scores_rating          -0.001425              1.000000

# %%
sns.pairplot(df_train[['number_of_reviews','review_scores_rating']])
plt.show()

# %% [markdown]
# There does not seem to be any issue with multicollinearity as the correlation values are very small.

# %% [markdown]
# ### 5.3. Predictive Power
#
# Finally, what two explanatory (or indicator) variables are suggested to bring the most predictive power to the final model? Do you have any concerns about making this interpretation?

# %% [markdown]
# Neighborhood[T.Broadway] and neighborhood[T.Wallingford] seem to bring the most predictive power to the final model since the magnitudes of their slopes are the greatest. There may be an issue with multicollinearity since if the neighborhood is Broadway it automatically cannot be Wallingford so the two variables are dependent.

# %% [markdown]
# ### 5.4. Overfitting Variables
#
# Based on the results of our backwards elimination algorithm, do you have any reason to believe that any of the explanatory variables in the full model were overfitting the model? If so, which one(s)?

# %% [markdown]
# Room_type was most likely overfitting the model since its elimination caused the AUC of the model to increase.

# %% [markdown]
# ## 💃🥳🕺🎉 Way to go on finishing the last lab!   💃🥳🕺🎉
